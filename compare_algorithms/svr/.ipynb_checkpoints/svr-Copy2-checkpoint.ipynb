# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import sys 
sys.path.append("../../") 
from compare_algorithms.utils import create_dataset
# %matplotlib notebook

# %%
filename = '../../data/week_data/data/washingtong_summer_20120701-20120707新.csv'
x_train, y_train, x_test, y_test = create_dataset(filename,seq_len=9)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((711, 9), (711,), (288, 9), (288,))

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 网格化搜索寻找最优参数
svr = GridSearchCV(
    SVR(kernel="rbf", gamma=0.1,verbose=True),
    param_grid={"C": [1e0, 1e1, 1e2, 1e3], "gamma": np.logspace(-2, 2, 5)},
)

# %%
# svr = SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1, verbose=True)

# %%
svr.fit(x_train, y_train)
# Out:
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -212.388232, rho = -6.706943
# nSV = 470, nBSV = 452
# [LibSVM]*
# optimization finished, #iter = 470
# obj = -194.284017, rho = -8.176236
# nSV = 472, nBSV = 452
# [LibSVM]*
# optimization finished, #iter = 525
# obj = -229.368712, rho = -7.282771
# nSV = 467, nBSV = 439
# [LibSVM]*
# optimization finished, #iter = 504
# obj = -216.472909, rho = -7.238776
# nSV = 461, nBSV = 441
# [LibSVM]*
# optimization finished, #iter = 425
# obj = -218.925863, rho = -7.293279
# nSV = 452, nBSV = 434
# [LibSVM]*
# optimization finished, #iter = 942
# obj = -257.957625, rho = -6.594638
# nSV = 479, nBSV = 377
# [LibSVM]*
# optimization finished, #iter = 918
# obj = -223.329888, rho = -8.625887
# nSV = 460, nBSV = 359
# [LibSVM]*
# optimization finished, #iter = 817
# obj = -305.277628, rho = -7.268513
# nSV = 464, nBSV = 367
# [LibSVM]*
# optimization finished, #iter = 915
# obj = -286.564167, rho = -7.071245
# nSV = 466, nBSV = 368
# [LibSVM]*
# optimization finished, #iter = 944
# obj = -284.725783, rho = -7.690235
# nSV = 463, nBSV = 365
# [LibSVM]*
# optimization finished, #iter = 816
# obj = -544.852141, rho = -7.640371
# nSV = 513, nBSV = 234
# [LibSVM]*
# optimization finished, #iter = 746
# obj = -497.148835, rho = -8.788270
# nSV = 489, nBSV = 241
# [LibSVM]*
# optimization finished, #iter = 746
# obj = -618.275168, rho = -8.054606
# nSV = 497, nBSV = 246
# [LibSVM]*
# optimization finished, #iter = 759
# obj = -583.484767, rho = -7.560555
# nSV = 507, nBSV = 238
# [LibSVM]*
# optimization finished, #iter = 745
# obj = -614.481444, rho = -8.345061
# nSV = 501, nBSV = 255
# [LibSVM]*
# optimization finished, #iter = 444
# obj = -904.791484, rho = -7.902359
# nSV = 554, nBSV = 407
# [LibSVM]*
# optimization finished, #iter = 440
# obj = -827.505782, rho = -8.769607
# nSV = 547, nBSV = 390
# [LibSVM]*
# optimization finished, #iter = 473
# obj = -896.598655, rho = -8.042385
# nSV = 555, nBSV = 389
# [LibSVM]*
# optimization finished, #iter = 500
# obj = -875.378776, rho = -7.290576
# nSV = 552, nBSV = 366
# [LibSVM]*
# optimization finished, #iter = 418
# obj = -973.813301, rho = -8.413712
# nSV = 552, nBSV = 406
# [LibSVM]*
# optimization finished, #iter = 467
# obj = -909.005141, rho = -7.907299
# nSV = 554, nBSV = 407
# [LibSVM]*
# optimization finished, #iter = 408
# obj = -879.437215, rho = -8.743547
# nSV = 548, nBSV = 400
# [LibSVM]*
# optimization finished, #iter = 469
# obj = -944.610380, rho = -7.995476
# nSV = 555, nBSV = 408
# [LibSVM]*
# optimization finished, #iter = 422
# obj = -915.656502, rho = -7.201806
# nSV = 557, nBSV = 394
# [LibSVM]*
# optimization finished, #iter = 443
# obj = -1023.043685, rho = -8.373857
# nSV = 553, nBSV = 420
# [LibSVM].*.*
# optimization finished, #iter = 2744
# obj = -1379.045690, rho = -6.457726
# nSV = 472, nBSV = 412
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2195
# obj = -1273.977366, rho = -8.548364
# nSV = 462, nBSV = 410
# [LibSVM].
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 3302
# obj = -1451.474360, rho = -7.339622
# nSV = 468, nBSV = 405
# [LibSVM].
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 3575
# obj = -1338.864262, rho = -7.198544
# nSV = 453, nBSV = 392
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2225
# obj = -1390.812701, rho = -7.206030
# nSV = 456, nBSV = 407
# [LibSVM]...*...*
# optimization finished, #iter = 6533
# obj = -954.607345, rho = -6.447289
# nSV = 483, nBSV = 207
# [LibSVM]...*..*
# optimization finished, #iter = 5879
# obj = -880.807917, rho = -8.340157
# nSV = 466, nBSV = 200
# [LibSVM]...*..*
# optimization finished, #iter = 5064
# obj = -1005.543639, rho = -7.094569
# nSV = 446, nBSV = 190
# [LibSVM]...*..*
# optimization finished, #iter = 5441
# obj = -918.163402, rho = -6.938307
# nSV = 453, nBSV = 184
# [LibSVM]...*...*
# optimization finished, #iter = 6077
# obj = -950.747184, rho = -7.183183
# nSV = 452, nBSV = 184
# [LibSVM].*
# optimization finished, #iter = 1450
# obj = -863.258732, rho = -7.500519
# nSV = 513, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1583
# obj = -737.814610, rho = -8.969833
# nSV = 502, nBSV = 1
# [LibSVM]*.*
# optimization finished, #iter = 1524
# obj = -1110.447647, rho = -8.159289
# nSV = 502, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1584
# obj = -1040.025057, rho = -7.764166
# nSV = 499, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1620
# obj = -1059.072439, rho = -8.293141
# nSV = 487, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 962
# obj = -1695.709613, rho = -7.926831
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1000
# obj = -1420.034589, rho = -8.771404
# nSV = 545, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 977
# obj = -1729.070042, rho = -8.086880
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1111
# obj = -1711.951503, rho = -7.618987
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 964
# obj = -1887.115559, rho = -8.306967
# nSV = 556, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1024
# obj = -1718.138756, rho = -7.915611
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 976
# obj = -1607.668765, rho = -8.590079
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 848
# obj = -1863.957773, rho = -7.935248
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1102
# obj = -1816.964199, rho = -7.489725
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 936
# obj = -2037.156011, rho = -8.149538
# nSV = 558, nBSV = 0
# [LibSVM]..........*........*.*
# optimization finished, #iter = 18898
# obj = -11501.840708, rho = -6.050343
# nSV = 466, nBSV = 364
# [LibSVM].............*..........*..*
# optimization finished, #iter = 24974
# obj = -10775.559776, rho = -9.606891
# nSV = 454, nBSV = 355
# [LibSVM]................*..........*
# optimization finished, #iter = 26227
# obj = -11766.593103, rho = -8.202266
# nSV = 462, nBSV = 344
# [LibSVM].............*......*
# optimization finished, #iter = 19684
# obj = -10852.774631, rho = -7.556075
# nSV = 450, nBSV = 350
# [LibSVM]..............*......*
# optimization finished, #iter = 20819
# obj = -11237.076154, rho = -7.897702
# nSV = 452, nBSV = 356
# [LibSVM].....................*..............*
# optimization finished, #iter = 35089
# obj = -3531.477515, rho = -6.846652
# nSV = 483, nBSV = 62
# [LibSVM]....................*...............*
# optimization finished, #iter = 35792
# obj = -3608.884278, rho = -8.542575
# nSV = 478, nBSV = 76
# [LibSVM]................*...........*
# optimization finished, #iter = 27936
# obj = -3386.085224, rho = -7.327610
# nSV = 476, nBSV = 66
# [LibSVM]..................*.............*.*
# optimization finished, #iter = 31803
# obj = -3130.097644, rho = -7.120439
# nSV = 464, nBSV = 57
# [LibSVM]..................*..........*
# optimization finished, #iter = 28480
# obj = -3103.557754, rho = -7.690570
# nSV = 465, nBSV = 61
# [LibSVM].*
# optimization finished, #iter = 1450
# obj = -863.258732, rho = -7.500519
# nSV = 513, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1681
# obj = -737.823014, rho = -8.969864
# nSV = 503, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1524
# obj = -1110.447647, rho = -8.159289
# nSV = 502, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1584
# obj = -1040.025057, rho = -7.764166
# nSV = 499, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1620
# obj = -1059.072439, rho = -8.293141
# nSV = 487, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 962
# obj = -1695.709613, rho = -7.926831
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1000
# obj = -1420.034589, rho = -8.771404
# nSV = 545, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 977
# obj = -1729.070042, rho = -8.086880
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1111
# obj = -1711.951503, rho = -7.618987
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 964
# obj = -1887.115559, rho = -8.306967
# nSV = 556, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1024
# obj = -1718.138756, rho = -7.915611
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 976
# obj = -1607.668765, rho = -8.590079
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 848
# obj = -1863.957773, rho = -7.935248
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1102
# obj = -1816.964199, rho = -7.489725
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 936
# obj = -2037.156011, rho = -8.149538
# nSV = 558, nBSV = 0
# [LibSVM].............................................................................................*.....................................................................................*.............................*
# optimization finished, #iter = 206342
# obj = -97172.451294, rho = -5.219775
# nSV = 465, nBSV = 302
# [LibSVM].........................................................................................................*...................................................................................................................*........................................*
# optimization finished, #iter = 259990
# obj = -92464.543721, rho = -10.382810
# nSV = 458, nBSV = 304
# [LibSVM]................................................................................................................*.............................................................................*...*
# optimization finished, #iter = 191861
# obj = -95811.582041, rho = -9.785020
# nSV = 459, nBSV = 281
# [LibSVM]..........................................................................................................*............................................................*................................*...*
# optimization finished, #iter = 200785
# obj = -88261.735082, rho = -6.416142
# nSV = 457, nBSV = 283
# [LibSVM]..................................................................................................*......................................................................................*..................*
# optimization finished, #iter = 202095
# obj = -91873.470586, rho = -9.308811
# nSV = 453, nBSV = 286
# [LibSVM]......................................................*...............................*.....*
# optimization finished, #iter = 89675
# obj = -7237.293643, rho = -6.826491
# nSV = 494, nBSV = 3
# [LibSVM]....................................................................*..................................*
# optimization finished, #iter = 102409
# obj = -7728.747916, rho = -8.744686
# nSV = 491, nBSV = 9
# [LibSVM]...................................................*..............................*
# optimization finished, #iter = 81638
# obj = -6646.547568, rho = -7.028659
# nSV = 490, nBSV = 4
# [LibSVM].......................................................*......................................*
# optimization finished, #iter = 93840
# obj = -6723.576807, rho = -6.888363
# nSV = 493, nBSV = 12
# [LibSVM]..................................................*................................*......*
# optimization finished, #iter = 87599
# obj = -6831.754986, rho = -7.706376
# nSV = 493, nBSV = 11
# [LibSVM].*
# optimization finished, #iter = 1450
# obj = -863.258732, rho = -7.500519
# nSV = 513, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1681
# obj = -737.823014, rho = -8.969864
# nSV = 503, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1524
# obj = -1110.447647, rho = -8.159289
# nSV = 502, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1584
# obj = -1040.025057, rho = -7.764166
# nSV = 499, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1620
# obj = -1059.072439, rho = -8.293141
# nSV = 487, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 962
# obj = -1695.709613, rho = -7.926831
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1000
# obj = -1420.034589, rho = -8.771404
# nSV = 545, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 977
# obj = -1729.070042, rho = -8.086880
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1111
# obj = -1711.951503, rho = -7.618987
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 964
# obj = -1887.115559, rho = -8.306967
# nSV = 556, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1024
# obj = -1718.138756, rho = -7.915611
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 976
# obj = -1607.668765, rho = -8.590079
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 848
# obj = -1863.957773, rho = -7.935248
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1102
# obj = -1816.964199, rho = -7.489725
# nSV = 553, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 936
# obj = -2037.156011, rho = -8.149538
# nSV = 558, nBSV = 0
# [LibSVM]..*.*
# optimization finished, #iter = 3574
# obj = -1713.897529, rho = -7.321981
# nSV = 575, nBSV = 518
# GridSearchCV(estimator=SVR(gamma=0.1, verbose=True),
#              param_grid={'C': [1.0, 10.0, 100.0, 1000.0],
#                          'gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
svr_predict = svr.predict(x_test)

# %%
#  画出预测的图像，第二幅图为预测的图像，把缺失的数据补上
fig,ax = plt.subplots(figsize=(10, 5),layout='constrained')
ax.set_title("washingtong_winter_20120101-20120107")
ax.plot(y_test,label='true')
ax.plot(svr_predict,label='predict')
ax.grid()
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def cal_mse(y_hat, y):
    mse = (np.square(y_hat - y)).mean()
    return mse

# %%
mse = cal_mse(svr_predict, y_test)
mse
# Out:
# 0.7040945899051407

# %%
df = pd.DataFrame(data={
                'true_value': y_test,
                'predict': svr_predict
            })
df.to_csv("result/washingtong_summer_20120701-20120707.csv", index=False)
