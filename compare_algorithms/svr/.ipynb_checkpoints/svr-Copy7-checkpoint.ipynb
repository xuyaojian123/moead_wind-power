# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import sys 
sys.path.append("../../") 
from compare_algorithms.utils import create_dataset
# %matplotlib notebook

# %%
filename = '../../data/week_data/data/California_autumn_20121001-20121007新.csv'
x_train, y_train, x_test, y_test = create_dataset(filename,seq_len=9)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((711, 9), (711,), (288, 9), (288,))

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 网格化搜索寻找最优参数
svr = GridSearchCV(
    SVR(kernel="rbf", gamma=0.1,verbose=True),
    param_grid={"C": [1e0, 1e1, 1e2, 1e3], "gamma": np.logspace(-2, 2, 5)},
)

# %%
# svr = SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1, verbose=True)

# %%
svr.fit(x_train, y_train)
# Out:
# [LibSVM]*
# optimization finished, #iter = 511
# obj = -196.156419, rho = -9.436619
# nSV = 376, nBSV = 357
# [LibSVM]*
# optimization finished, #iter = 608
# obj = -181.817783, rho = -9.683146
# nSV = 374, nBSV = 355
# [LibSVM]*
# optimization finished, #iter = 518
# obj = -217.197933, rho = -9.947693
# nSV = 400, nBSV = 377
# [LibSVM]*
# optimization finished, #iter = 500
# obj = -213.232658, rho = -10.084447
# nSV = 400, nBSV = 379
# [LibSVM]*
# optimization finished, #iter = 371
# obj = -205.338357, rho = -9.926432
# nSV = 374, nBSV = 354
# [LibSVM]*
# optimization finished, #iter = 806
# obj = -349.232457, rho = -10.133246
# nSV = 362, nBSV = 286
# [LibSVM]*
# optimization finished, #iter = 751
# obj = -310.842989, rho = -9.586935
# nSV = 334, nBSV = 269
# [LibSVM]*
# optimization finished, #iter = 886
# obj = -386.427771, rho = -10.613059
# nSV = 390, nBSV = 292
# [LibSVM]*
# optimization finished, #iter = 886
# obj = -365.359175, rho = -10.834411
# nSV = 375, nBSV = 283
# [LibSVM]*
# optimization finished, #iter = 984
# obj = -369.396198, rho = -10.748409
# nSV = 367, nBSV = 275
# [LibSVM]*.*
# optimization finished, #iter = 1019
# obj = -968.848568, rho = -8.771811
# nSV = 422, nBSV = 223
# [LibSVM]*.*
# optimization finished, #iter = 1033
# obj = -796.470701, rho = -7.773005
# nSV = 414, nBSV = 234
# [LibSVM]*
# optimization finished, #iter = 758
# obj = -1201.839861, rho = -10.185442
# nSV = 440, nBSV = 284
# [LibSVM]*
# optimization finished, #iter = 904
# obj = -1194.388596, rho = -9.754257
# nSV = 463, nBSV = 277
# [LibSVM]*
# optimization finished, #iter = 870
# obj = -1233.833052, rho = -9.327751
# nSV = 430, nBSV = 276
# [LibSVM]*
# optimization finished, #iter = 491
# obj = -1485.180196, rho = -8.415688
# nSV = 535, nBSV = 389
# [LibSVM]*
# optimization finished, #iter = 520
# obj = -1466.642339, rho = -8.203152
# nSV = 530, nBSV = 396
# [LibSVM]*
# optimization finished, #iter = 601
# obj = -1606.910038, rho = -10.172432
# nSV = 558, nBSV = 379
# [LibSVM]*
# optimization finished, #iter = 420
# obj = -1862.845543, rho = -9.660313
# nSV = 553, nBSV = 468
# [LibSVM]*
# optimization finished, #iter = 507
# obj = -1790.837547, rho = -8.247189
# nSV = 531, nBSV = 397
# [LibSVM]*
# optimization finished, #iter = 429
# obj = -1592.364800, rho = -8.369588
# nSV = 554, nBSV = 428
# [LibSVM]*
# optimization finished, #iter = 398
# obj = -1636.031033, rho = -8.284414
# nSV = 554, nBSV = 453
# [LibSVM]*
# optimization finished, #iter = 421
# obj = -1689.158856, rho = -10.057497
# nSV = 566, nBSV = 457
# [LibSVM]*
# optimization finished, #iter = 359
# obj = -2026.716095, rho = -9.749145
# nSV = 563, nBSV = 508
# [LibSVM]*
# optimization finished, #iter = 400
# obj = -1950.507834, rho = -8.301015
# nSV = 558, nBSV = 458
# [LibSVM]..*.*
# optimization finished, #iter = 3185
# obj = -659.355033, rho = -9.935967
# nSV = 304, nBSV = 255
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2561
# obj = -504.128939, rho = -9.507667
# nSV = 274, nBSV = 232
# [LibSVM]..*..*
# optimization finished, #iter = 4044
# obj = -773.710872, rho = -10.179850
# nSV = 336, nBSV = 283
# [LibSVM]..*
# optimization finished, #iter = 2588
# obj = -759.210192, rho = -10.275392
# nSV = 319, nBSV = 273
# [LibSVM].
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 3567
# obj = -677.518237, rho = -10.207478
# nSV = 298, nBSV = 250
# [LibSVM]...*..*
# optimization finished, #iter = 5358
# obj = -538.743464, rho = -10.203177
# nSV = 301, nBSV = 98
# [LibSVM]...*..*
# optimization finished, #iter = 5358
# obj = -450.178618, rho = -9.671662
# nSV = 261, nBSV = 90
# [LibSVM]..*..*
# optimization finished, #iter = 4869
# obj = -625.463620, rho = -10.728272
# nSV = 336, nBSV = 112
# [LibSVM]..*..*
# optimization finished, #iter = 4763
# obj = -587.999290, rho = -10.900322
# nSV = 306, nBSV = 93
# [LibSVM]...*..*
# optimization finished, #iter = 5287
# obj = -577.795500, rho = -10.731025
# nSV = 312, nBSV = 101
# [LibSVM].*.*
# optimization finished, #iter = 2542
# obj = -1896.928136, rho = -10.694865
# nSV = 406, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2682
# obj = -1416.110678, rho = -9.284783
# nSV = 383, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2670
# obj = -2117.567797, rho = -11.646905
# nSV = 438, nBSV = 1
# [LibSVM]..*
# optimization finished, #iter = 2921
# obj = -2023.094278, rho = -11.702718
# nSV = 435, nBSV = 1
# [LibSVM].*.*
# optimization finished, #iter = 2736
# obj = -2198.120787, rho = -11.478872
# nSV = 409, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1306
# obj = -4263.989613, rho = -8.969962
# nSV = 536, nBSV = 1
# [LibSVM]*.*
# optimization finished, #iter = 1400
# obj = -3801.584730, rho = -8.248985
# nSV = 525, nBSV = 7
# [LibSVM]*.*
# optimization finished, #iter = 1246
# obj = -5060.164383, rho = -10.153209
# nSV = 554, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1320
# obj = -5143.941927, rho = -9.984972
# nSV = 549, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1443
# obj = -5433.988696, rho = -9.427637
# nSV = 538, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1372
# obj = -4796.635450, rho = -8.550922
# nSV = 557, nBSV = 7
# [LibSVM]*
# optimization finished, #iter = 991
# obj = -4656.656944, rho = -8.106446
# nSV = 542, nBSV = 9
# [LibSVM]*.*
# optimization finished, #iter = 1291
# obj = -5482.097033, rho = -10.028181
# nSV = 565, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1115
# obj = -6245.249695, rho = -9.466439
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1056
# obj = -6379.133518, rho = -8.889122
# nSV = 561, nBSV = 4
# [LibSVM]...........*.................*
# optimization finished, #iter = 28788
# obj = -3524.339498, rho = -10.071782
# nSV = 278, nBSV = 191
# [LibSVM]..............*.........*
# optimization finished, #iter = 23162
# obj = -2315.782897, rho = -9.292109
# nSV = 242, nBSV = 164
# [LibSVM]...............*...........*
# optimization finished, #iter = 26715
# obj = -4511.487573, rho = -9.574617
# nSV = 320, nBSV = 222
# [LibSVM]..............*............*
# optimization finished, #iter = 26494
# obj = -4354.156628, rho = -9.898803
# nSV = 295, nBSV = 194
# [LibSVM]..............*....*
# optimization finished, #iter = 18058
# obj = -3659.638994, rho = -9.513615
# nSV = 265, nBSV = 179
# [LibSVM]...............*.............*
# optimization finished, #iter = 28174
# obj = -860.591635, rho = -9.914030
# nSV = 303, nBSV = 23
# [LibSVM]............*........*.*
# optimization finished, #iter = 21564
# obj = -714.448261, rho = -9.502882
# nSV = 252, nBSV = 21
# [LibSVM]..............*.........*
# optimization finished, #iter = 23648
# obj = -1017.270218, rho = -10.577694
# nSV = 332, nBSV = 31
# [LibSVM]..........*......*
# optimization finished, #iter = 16804
# obj = -897.284356, rho = -10.678866
# nSV = 305, nBSV = 18
# [LibSVM]............*.............*.*
# optimization finished, #iter = 26667
# obj = -753.403218, rho = -10.485199
# nSV = 295, nBSV = 10
# [LibSVM].*.*
# optimization finished, #iter = 2542
# obj = -1896.928136, rho = -10.694865
# nSV = 406, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2682
# obj = -1416.110678, rho = -9.284783
# nSV = 383, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2637
# obj = -2117.625317, rho = -11.646357
# nSV = 435, nBSV = 0
# [LibSVM]..*.*
# optimization finished, #iter = 3013
# obj = -2023.094650, rho = -11.702683
# nSV = 435, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2736
# obj = -2198.120787, rho = -11.478872
# nSV = 409, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1306
# obj = -4264.006203, rho = -8.970380
# nSV = 536, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1354
# obj = -3802.214856, rho = -8.254779
# nSV = 525, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1246
# obj = -5060.164383, rho = -10.153209
# nSV = 554, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1320
# obj = -5143.941927, rho = -9.984972
# nSV = 549, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1443
# obj = -5433.988696, rho = -9.427637
# nSV = 538, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1292
# obj = -4797.031596, rho = -8.554665
# nSV = 557, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1083
# obj = -4657.735339, rho = -8.113134
# nSV = 542, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1291
# obj = -5482.097033, rho = -10.028181
# nSV = 565, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1115
# obj = -6245.249695, rho = -9.466439
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1051
# obj = -6379.179983, rho = -8.889754
# nSV = 560, nBSV = 0
# [LibSVM]..........................................................................................*.....................................................................................*
# optimization finished, #iter = 175733
# obj = -22195.672092, rho = -5.993601
# nSV = 284, nBSV = 140
# [LibSVM]..................................................................................................................*..................................................................*.*
# optimization finished, #iter = 180703
# obj = -14812.229450, rho = -7.938512
# nSV = 247, nBSV = 124
# [LibSVM].....................................................................................................*............................................................................................................*....................................*
# optimization finished, #iter = 244220
# obj = -30455.068693, rho = -7.676792
# nSV = 327, nBSV = 173
# [LibSVM]..........................................................................................*............................................................................................................................*..................*
# optimization finished, #iter = 232049
# obj = -29213.343804, rho = -8.368326
# nSV = 307, nBSV = 148
# [LibSVM].........................................................................................................*....................................................................................................................*........................................................................*................................................*
# optimization finished, #iter = 339972
# obj = -23194.254046, rho = -7.981363
# nSV = 269, nBSV = 122
# [LibSVM].......................................*..............................................*............*
# optimization finished, #iter = 96458
# obj = -1430.022397, rho = -9.815942
# nSV = 329, nBSV = 5
# [LibSVM].....................................*...................................*..*
# optimization finished, #iter = 73710
# obj = -1405.374645, rho = -9.377952
# nSV = 284, nBSV = 5
# [LibSVM]......................................................*..............................................................*..................................*
# optimization finished, #iter = 150205
# obj = -1988.167614, rho = -10.279923
# nSV = 366, nBSV = 7
# [LibSVM]...............................*..............................*........*
# optimization finished, #iter = 68524
# obj = -1564.207299, rho = -10.352287
# nSV = 329, nBSV = 5
# [LibSVM].........................*...........................*...............*
# optimization finished, #iter = 67066
# obj = -892.116469, rho = -10.485181
# nSV = 309, nBSV = 2
# [LibSVM].*.*
# optimization finished, #iter = 2542
# obj = -1896.928136, rho = -10.694865
# nSV = 406, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2682
# obj = -1416.110678, rho = -9.284783
# nSV = 383, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2637
# obj = -2117.625317, rho = -11.646357
# nSV = 435, nBSV = 0
# [LibSVM]..*.*
# optimization finished, #iter = 3013
# obj = -2023.094650, rho = -11.702683
# nSV = 435, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2736
# obj = -2198.120787, rho = -11.478872
# nSV = 409, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1306
# obj = -4264.006203, rho = -8.970380
# nSV = 536, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1354
# obj = -3802.214856, rho = -8.254779
# nSV = 525, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1246
# obj = -5060.164383, rho = -10.153209
# nSV = 554, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1320
# obj = -5143.941927, rho = -9.984972
# nSV = 549, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1443
# obj = -5433.988696, rho = -9.427637
# nSV = 538, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1292
# obj = -4797.031596, rho = -8.554665
# nSV = 557, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1083
# obj = -4657.735339, rho = -8.113134
# nSV = 542, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1291
# obj = -5482.097033, rho = -10.028181
# nSV = 565, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1115
# obj = -6245.249695, rho = -9.466439
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1051
# obj = -6379.179983, rho = -8.889754
# nSV = 560, nBSV = 0
# [LibSVM]................*......................*
# optimization finished, #iter = 38265
# obj = -4694.450710, rho = -9.426111
# nSV = 345, nBSV = 241
# GridSearchCV(estimator=SVR(gamma=0.1, verbose=True),
#              param_grid={'C': [1.0, 10.0, 100.0, 1000.0],
#                          'gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
svr_predict = svr.predict(x_test)

# %%
#  画出预测的图像，第二幅图为预测的图像，把缺失的数据补上
fig,ax = plt.subplots(figsize=(10, 5),layout='constrained')
ax.set_title("washingtong_winter_20120101-20120107")
ax.plot(y_test,label='true')
ax.plot(svr_predict,label='predict')
ax.grid()
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def cal_mse(y_hat, y):
    mse = (np.square(y_hat - y)).mean()
    return mse

# %%
mse = cal_mse(svr_predict, y_test)
mse
# Out:
# 0.016147414153232634

# %%
df = pd.DataFrame(data={
                'true_value': y_test,
                'predict': svr_predict
            })
df.to_csv("result/California_autumn_20121001-20121007.csv", index=False)
