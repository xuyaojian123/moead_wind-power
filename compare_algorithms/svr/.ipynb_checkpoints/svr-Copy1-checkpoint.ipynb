# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import sys 
sys.path.append("../../") 
from compare_algorithms.utils import create_dataset
# %matplotlib notebook

# %%
filename = '../../data/week_data/data/washingtong_spring_20120401-20120407新.csv'
x_train, y_train, x_test, y_test = create_dataset(filename,seq_len=9)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((711, 9), (711,), (288, 9), (288,))

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 网格化搜索寻找最优参数
svr = GridSearchCV(
    SVR(kernel="rbf", gamma=0.1,verbose=True),
    param_grid={"C": [1e0, 1e1, 1e2, 1e3], "gamma": np.logspace(-2, 2, 5)},
)

# %%
# svr = SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1, verbose=True)

# %%
svr.fit(x_train, y_train)
# Out:
# [LibSVM]*
# optimization finished, #iter = 453
# obj = -239.648243, rho = -9.373717
# nSV = 438, nBSV = 417
# [LibSVM]*
# optimization finished, #iter = 494
# obj = -173.834022, rho = -7.521071
# nSV = 408, nBSV = 391
# [LibSVM]*
# optimization finished, #iter = 480
# obj = -255.425762, rho = -8.697660
# nSV = 427, nBSV = 401
# [LibSVM]*
# optimization finished, #iter = 549
# obj = -233.807616, rho = -8.553766
# nSV = 411, nBSV = 386
# [LibSVM]*
# optimization finished, #iter = 524
# obj = -241.271826, rho = -8.680996
# nSV = 417, nBSV = 395
# [LibSVM]*
# optimization finished, #iter = 900
# obj = -318.851634, rho = -8.815101
# nSV = 445, nBSV = 341
# [LibSVM]*
# optimization finished, #iter = 978
# obj = -212.324230, rho = -8.347518
# nSV = 413, nBSV = 314
# [LibSVM]*
# optimization finished, #iter = 769
# obj = -344.300822, rho = -8.454791
# nSV = 434, nBSV = 327
# [LibSVM]*
# optimization finished, #iter = 868
# obj = -309.729416, rho = -8.113139
# nSV = 423, nBSV = 329
# [LibSVM]*
# optimization finished, #iter = 859
# obj = -334.306441, rho = -8.470238
# nSV = 434, nBSV = 337
# [LibSVM]*
# optimization finished, #iter = 815
# obj = -845.228763, rho = -9.218357
# nSV = 503, nBSV = 301
# [LibSVM]*
# optimization finished, #iter = 966
# obj = -701.235895, rho = -8.390948
# nSV = 476, nBSV = 251
# [LibSVM]*
# optimization finished, #iter = 754
# obj = -1004.484988, rho = -8.257660
# nSV = 502, nBSV = 314
# [LibSVM]*
# optimization finished, #iter = 756
# obj = -842.404745, rho = -7.892327
# nSV = 484, nBSV = 298
# [LibSVM]*
# optimization finished, #iter = 795
# obj = -976.203405, rho = -8.415925
# nSV = 491, nBSV = 306
# [LibSVM]*
# optimization finished, #iter = 438
# obj = -1252.752361, rho = -9.763353
# nSV = 555, nBSV = 417
# [LibSVM]*
# optimization finished, #iter = 406
# obj = -1284.351499, rho = -8.356567
# nSV = 565, nBSV = 456
# [LibSVM]*
# optimization finished, #iter = 397
# obj = -1480.171096, rho = -7.530075
# nSV = 553, nBSV = 456
# [LibSVM]*
# optimization finished, #iter = 389
# obj = -1335.237340, rho = -8.559727
# nSV = 563, nBSV = 457
# [LibSVM]*
# optimization finished, #iter = 400
# obj = -1567.043710, rho = -8.095434
# nSV = 564, nBSV = 478
# [LibSVM]*
# optimization finished, #iter = 406
# obj = -1277.020999, rho = -9.837025
# nSV = 558, nBSV = 429
# [LibSVM]*
# optimization finished, #iter = 388
# obj = -1354.500172, rho = -8.328758
# nSV = 567, nBSV = 471
# [LibSVM]*
# optimization finished, #iter = 388
# obj = -1526.342102, rho = -7.455288
# nSV = 554, nBSV = 465
# [LibSVM]*
# optimization finished, #iter = 369
# obj = -1390.814427, rho = -8.543473
# nSV = 563, nBSV = 478
# [LibSVM]*
# optimization finished, #iter = 391
# obj = -1632.647644, rho = -8.043110
# nSV = 562, nBSV = 494
# [LibSVM]..*.*
# optimization finished, #iter = 3928
# obj = -1232.599912, rho = -9.813471
# nSV = 417, nBSV = 350
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2857
# obj = -844.719574, rho = -8.150985
# nSV = 365, nBSV = 324
# [LibSVM].
# Warning: using -h 0 may be faster
# *...*
# optimization finished, #iter = 4049
# obj = -1229.909872, rho = -9.464816
# nSV = 397, nBSV = 325
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2421
# obj = -1074.605854, rho = -9.248869
# nSV = 378, nBSV = 314
# [LibSVM]..*..*
# optimization finished, #iter = 4021
# obj = -1149.266212, rho = -9.491176
# nSV = 381, nBSV = 314
# [LibSVM]...*...*
# optimization finished, #iter = 6264
# obj = -830.207801, rho = -9.184036
# nSV = 420, nBSV = 141
# [LibSVM]...*..*
# optimization finished, #iter = 5526
# obj = -520.693138, rho = -8.649567
# nSV = 359, nBSV = 135
# [LibSVM]...*..*
# optimization finished, #iter = 5050
# obj = -823.060171, rho = -9.012660
# nSV = 392, nBSV = 115
# [LibSVM]...*..*
# optimization finished, #iter = 5816
# obj = -759.148670, rho = -8.856424
# nSV = 386, nBSV = 127
# [LibSVM]...*..*
# optimization finished, #iter = 5931
# obj = -790.033569, rho = -9.013720
# nSV = 391, nBSV = 124
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -1571.436586, rho = -8.945042
# nSV = 477, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2385
# obj = -992.187751, rho = -9.024588
# nSV = 452, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2064
# obj = -1787.537735, rho = -8.537271
# nSV = 486, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2007
# obj = -1425.821341, rho = -7.857104
# nSV = 465, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2125
# obj = -1721.189418, rho = -8.538659
# nSV = 464, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1105
# obj = -2897.127325, rho = -8.975422
# nSV = 548, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1237
# obj = -2660.092142, rho = -8.232871
# nSV = 560, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 984
# obj = -3455.676245, rho = -7.922851
# nSV = 557, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1181
# obj = -2973.774291, rho = -8.151725
# nSV = 559, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1243
# obj = -3562.297149, rho = -8.088970
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1194
# obj = -3158.206696, rho = -8.929189
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1045
# obj = -3173.431518, rho = -7.990158
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 813
# obj = -3825.337288, rho = -7.612183
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1066
# obj = -3320.306880, rho = -8.061178
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1147
# obj = -4053.612073, rho = -7.862542
# nSV = 563, nBSV = 0
# [LibSVM].............*.........*
# optimization finished, #iter = 22998
# obj = -8251.320688, rho = -9.496709
# nSV = 416, nBSV = 293
# [LibSVM]................*..........*
# optimization finished, #iter = 26684
# obj = -6011.676526, rho = -9.524015
# nSV = 349, nBSV = 272
# [LibSVM]..............*.............*
# optimization finished, #iter = 27449
# obj = -7991.811861, rho = -9.631044
# nSV = 388, nBSV = 263
# [LibSVM].............*..............*
# optimization finished, #iter = 27944
# obj = -6672.917282, rho = -9.364357
# nSV = 383, nBSV = 264
# [LibSVM]................*..............*
# optimization finished, #iter = 30061
# obj = -7251.161932, rho = -9.592500
# nSV = 381, nBSV = 258
# [LibSVM]..................*..........*
# optimization finished, #iter = 28019
# obj = -1946.196821, rho = -9.241386
# nSV = 430, nBSV = 55
# [LibSVM].................*..............*.*
# optimization finished, #iter = 32279
# obj = -1434.501677, rho = -8.615102
# nSV = 376, nBSV = 43
# [LibSVM]...............*.......*
# optimization finished, #iter = 22354
# obj = -1705.723190, rho = -9.134171
# nSV = 412, nBSV = 30
# [LibSVM]..............*...........*.....*
# optimization finished, #iter = 29999
# obj = -1792.065448, rho = -8.869343
# nSV = 382, nBSV = 48
# [LibSVM]................*...........*
# optimization finished, #iter = 27189
# obj = -1625.129714, rho = -9.001111
# nSV = 390, nBSV = 35
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -1571.436586, rho = -8.945042
# nSV = 477, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2385
# obj = -992.187751, rho = -9.024588
# nSV = 452, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2064
# obj = -1787.537735, rho = -8.537271
# nSV = 486, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2007
# obj = -1425.821341, rho = -7.857104
# nSV = 465, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2125
# obj = -1721.189418, rho = -8.538659
# nSV = 464, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1105
# obj = -2897.127325, rho = -8.975422
# nSV = 548, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1237
# obj = -2660.092142, rho = -8.232871
# nSV = 560, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 984
# obj = -3455.676245, rho = -7.922851
# nSV = 557, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1181
# obj = -2973.774291, rho = -8.151725
# nSV = 559, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1243
# obj = -3562.297149, rho = -8.088970
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1194
# obj = -3158.206696, rho = -8.929189
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1045
# obj = -3173.431518, rho = -7.990158
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 813
# obj = -3825.337288, rho = -7.612183
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1066
# obj = -3320.306880, rho = -8.061178
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1147
# obj = -4053.612073, rho = -7.862542
# nSV = 563, nBSV = 0
# [LibSVM]......................................................................................................................*....................................................................................*............*
# optimization finished, #iter = 214726
# obj = -59111.099418, rho = -9.532792
# nSV = 418, nBSV = 223
# [LibSVM]........................................................................................................................*...........................................................................................................................*..................................*
# optimization finished, #iter = 277872
# obj = -45480.960184, rho = -11.942399
# nSV = 359, nBSV = 211
# [LibSVM]..................................................................................................*...............................................................................................*...............................*
# optimization finished, #iter = 223470
# obj = -55864.675797, rho = -10.823955
# nSV = 391, nBSV = 205
# [LibSVM]...........................................................................................................*...........................................................................................................*....*
# optimization finished, #iter = 218600
# obj = -47089.691784, rho = -11.185021
# nSV = 375, nBSV = 206
# [LibSVM]............................................................................................................*.............................................................................................................................*........................................*
# optimization finished, #iter = 273163
# obj = -49800.472763, rho = -10.265786
# nSV = 378, nBSV = 196
# [LibSVM]..............................................*................................................*......*
# optimization finished, #iter = 100462
# obj = -3513.016720, rho = -9.275162
# nSV = 443, nBSV = 3
# [LibSVM].......................................................*.............................................................*.........*
# optimization finished, #iter = 125561
# obj = -2972.465764, rho = -8.746286
# nSV = 403, nBSV = 3
# [LibSVM]....................................*........................................*...*
# optimization finished, #iter = 78807
# obj = -2526.516657, rho = -9.241575
# nSV = 433, nBSV = 2
# [LibSVM]...........................................*................................................*...........................*.*
# optimization finished, #iter = 118309
# obj = -3415.489709, rho = -9.031076
# nSV = 412, nBSV = 3
# [LibSVM]...........................................*.................................................*.............*
# optimization finished, #iter = 105090
# obj = -2748.386741, rho = -9.080217
# nSV = 422, nBSV = 6
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -1571.436586, rho = -8.945042
# nSV = 477, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2385
# obj = -992.187751, rho = -9.024588
# nSV = 452, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2064
# obj = -1787.537735, rho = -8.537271
# nSV = 486, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2007
# obj = -1425.821341, rho = -7.857104
# nSV = 465, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2125
# obj = -1721.189418, rho = -8.538659
# nSV = 464, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1105
# obj = -2897.127325, rho = -8.975422
# nSV = 548, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1237
# obj = -2660.092142, rho = -8.232871
# nSV = 560, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 984
# obj = -3455.676245, rho = -7.922851
# nSV = 557, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1181
# obj = -2973.774291, rho = -8.151725
# nSV = 559, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1243
# obj = -3562.297149, rho = -8.088970
# nSV = 563, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1194
# obj = -3158.206696, rho = -8.929189
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1045
# obj = -3173.431518, rho = -7.990158
# nSV = 558, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 813
# obj = -3825.337288, rho = -7.612183
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1066
# obj = -3320.306880, rho = -8.061178
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1147
# obj = -4053.612073, rho = -7.862542
# nSV = 563, nBSV = 0
# [LibSVM]...................*..........*
# optimization finished, #iter = 29587
# obj = -9244.640577, rho = -9.636614
# nSV = 480, nBSV = 358
# GridSearchCV(estimator=SVR(gamma=0.1, verbose=True),
#              param_grid={'C': [1.0, 10.0, 100.0, 1000.0],
#                          'gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
svr_predict = svr.predict(x_test)

# %%
#  画出预测的图像，第二幅图为预测的图像，把缺失的数据补上
fig,ax = plt.subplots(figsize=(10, 5),layout='constrained')
ax.set_title("washingtong_winter_20120101-20120107")
ax.plot(y_test,label='true')
ax.plot(svr_predict,label='predict')
ax.grid()
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def cal_mse(y_hat, y):
    mse = (np.square(y_hat - y)).mean()
    return mse

# %%
mse = cal_mse(svr_predict, y_test)
mse
# Out:
# 0.28775446261886073

# %%
df = pd.DataFrame(data={
                'true_value': y_test,
                'predict': svr_predict
            })
df.to_csv("result/washingtong_spring_20120401-20120407.csv", index=False)
