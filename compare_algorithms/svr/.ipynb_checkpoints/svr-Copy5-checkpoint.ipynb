# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import sys 
sys.path.append("../../") 
from compare_algorithms.utils import create_dataset
# %matplotlib notebook

# %%
filename = '../../data/week_data/data/California_spring_20120401-20120407新.csv'
x_train, y_train, x_test, y_test = create_dataset(filename,seq_len=9)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((711, 9), (711,), (288, 9), (288,))

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 网格化搜索寻找最优参数
svr = GridSearchCV(
    SVR(kernel="rbf", gamma=0.1,verbose=True),
    param_grid={"C": [1e0, 1e1, 1e2, 1e3], "gamma": np.logspace(-2, 2, 5)},
)

# %%
# svr = SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1, verbose=True)

# %%
svr.fit(x_train, y_train)
# Out:
# [LibSVM]*
# optimization finished, #iter = 451
# obj = -247.457923, rho = -5.795848
# nSV = 424, nBSV = 400
# [LibSVM]*
# optimization finished, #iter = 548
# obj = -276.000026, rho = -5.847994
# nSV = 437, nBSV = 414
# [LibSVM]*
# optimization finished, #iter = 545
# obj = -206.832382, rho = -4.551277
# nSV = 412, nBSV = 389
# [LibSVM]*
# optimization finished, #iter = 450
# obj = -188.946333, rho = -6.679332
# nSV = 402, nBSV = 382
# [LibSVM]*
# optimization finished, #iter = 579
# obj = -260.177620, rho = -5.551910
# nSV = 426, nBSV = 402
# [LibSVM]*
# optimization finished, #iter = 908
# obj = -279.407463, rho = -6.055726
# nSV = 399, nBSV = 290
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -332.298871, rho = -6.164271
# nSV = 442, nBSV = 333
# [LibSVM]*
# optimization finished, #iter = 755
# obj = -230.145582, rho = -5.433727
# nSV = 388, nBSV = 294
# [LibSVM]*
# optimization finished, #iter = 868
# obj = -225.908332, rho = -6.882636
# nSV = 379, nBSV = 286
# [LibSVM]*
# optimization finished, #iter = 806
# obj = -314.354052, rho = -6.147788
# nSV = 394, nBSV = 288
# [LibSVM]*
# optimization finished, #iter = 893
# obj = -563.407732, rho = -6.090139
# nSV = 466, nBSV = 221
# [LibSVM]*
# optimization finished, #iter = 777
# obj = -665.184223, rho = -6.003486
# nSV = 491, nBSV = 246
# [LibSVM]*.*
# optimization finished, #iter = 1051
# obj = -389.484288, rho = -5.594741
# nSV = 440, nBSV = 201
# [LibSVM]*.*
# optimization finished, #iter = 1141
# obj = -593.522452, rho = -6.046913
# nSV = 445, nBSV = 227
# [LibSVM]*
# optimization finished, #iter = 879
# obj = -649.228174, rho = -5.815663
# nSV = 460, nBSV = 245
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -945.461969, rho = -5.742231
# nSV = 542, nBSV = 354
# [LibSVM]*
# optimization finished, #iter = 444
# obj = -1043.877937, rho = -5.336811
# nSV = 548, nBSV = 378
# [LibSVM]*
# optimization finished, #iter = 497
# obj = -789.449025, rho = -4.884099
# nSV = 548, nBSV = 350
# [LibSVM]*
# optimization finished, #iter = 532
# obj = -1127.111065, rho = -4.952699
# nSV = 549, nBSV = 380
# [LibSVM]*
# optimization finished, #iter = 499
# obj = -1077.176427, rho = -4.994918
# nSV = 557, nBSV = 381
# [LibSVM]*
# optimization finished, #iter = 434
# obj = -1069.536769, rho = -5.745902
# nSV = 547, nBSV = 390
# [LibSVM]*
# optimization finished, #iter = 503
# obj = -1110.037183, rho = -5.353099
# nSV = 552, nBSV = 389
# [LibSVM]*
# optimization finished, #iter = 414
# obj = -943.482120, rho = -4.817872
# nSV = 552, nBSV = 403
# [LibSVM]*
# optimization finished, #iter = 478
# obj = -1293.888716, rho = -4.877017
# nSV = 554, nBSV = 423
# [LibSVM]*
# optimization finished, #iter = 449
# obj = -1213.075782, rho = -4.916213
# nSV = 558, nBSV = 422
# [LibSVM]..*.*
# optimization finished, #iter = 3678
# obj = -1441.101621, rho = -5.386214
# nSV = 372, nBSV = 312
# [LibSVM].*.*
# optimization finished, #iter = 2912
# obj = -1750.728940, rho = -5.467724
# nSV = 414, nBSV = 349
# [LibSVM].*.*.*
# optimization finished, #iter = 2900
# obj = -1266.122847, rho = -4.015817
# nSV = 364, nBSV = 307
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2480
# obj = -1071.087133, rho = -6.268481
# nSV = 344, nBSV = 298
# [LibSVM]..*.*
# optimization finished, #iter = 3249
# obj = -1520.865703, rho = -5.431189
# nSV = 376, nBSV = 311
# [LibSVM]...*.*
# optimization finished, #iter = 4683
# obj = -792.293276, rho = -5.721630
# nSV = 377, nBSV = 126
# [LibSVM]..*...*
# optimization finished, #iter = 5010
# obj = -958.739211, rho = -6.113844
# nSV = 426, nBSV = 136
# [LibSVM]...*.*
# optimization finished, #iter = 4985
# obj = -689.988034, rho = -5.722480
# nSV = 361, nBSV = 124
# [LibSVM]..*...*
# optimization finished, #iter = 5062
# obj = -569.503327, rho = -6.914534
# nSV = 325, nBSV = 114
# [LibSVM]..*...*
# optimization finished, #iter = 5026
# obj = -811.461426, rho = -6.043432
# nSV = 371, nBSV = 111
# [LibSVM].**.*
# optimization finished, #iter = 1902
# obj = -859.471852, rho = -6.154281
# nSV = 451, nBSV = 2
# [LibSVM].*
# optimization finished, #iter = 1722
# obj = -1071.377238, rho = -6.186248
# nSV = 484, nBSV = 4
# [LibSVM].*.*
# optimization finished, #iter = 2116
# obj = -622.160175, rho = -5.679557
# nSV = 427, nBSV = 4
# [LibSVM].*.*
# optimization finished, #iter = 2452
# obj = -887.640921, rho = -6.532032
# nSV = 434, nBSV = 4
# [LibSVM].*.*
# optimization finished, #iter = 2026
# obj = -1048.815290, rho = -6.049801
# nSV = 448, nBSV = 2
# [LibSVM]*.*
# optimization finished, #iter = 1300
# obj = -1894.307939, rho = -6.264945
# nSV = 551, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1086
# obj = -2234.212272, rho = -5.951189
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1387
# obj = -1257.591535, rho = -5.177622
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1334
# obj = -2345.888334, rho = -5.902824
# nSV = 553, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1390
# obj = -2317.776513, rho = -5.721115
# nSV = 550, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 926
# obj = -2520.961324, rho = -6.205440
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 925
# obj = -2660.371129, rho = -5.958832
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1201
# obj = -1795.314738, rho = -4.991581
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1035
# obj = -3176.101298, rho = -5.684756
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1220
# obj = -3040.340792, rho = -5.466987
# nSV = 551, nBSV = 0
# [LibSVM]...........*........*
# optimization finished, #iter = 19602
# obj = -10788.153985, rho = -5.862342
# nSV = 368, nBSV = 255
# [LibSVM]..................*............*.*
# optimization finished, #iter = 31016
# obj = -12865.327617, rho = -5.868701
# nSV = 420, nBSV = 290
# [LibSVM]..............*......*
# optimization finished, #iter = 20684
# obj = -8803.544567, rho = -3.870170
# nSV = 367, nBSV = 246
# [LibSVM]................*...............*
# optimization finished, #iter = 31965
# obj = -7459.211315, rho = -5.556005
# nSV = 329, nBSV = 234
# [LibSVM]..............*..............*
# optimization finished, #iter = 28084
# obj = -10561.602450, rho = -5.857175
# nSV = 371, nBSV = 243
# [LibSVM]..............*...........*
# optimization finished, #iter = 25387
# obj = -2337.314937, rho = -5.803591
# nSV = 377, nBSV = 28
# [LibSVM]...............*........*
# optimization finished, #iter = 23569
# obj = -2682.755326, rho = -6.179824
# nSV = 434, nBSV = 44
# [LibSVM]..............*...........*
# optimization finished, #iter = 25052
# obj = -2024.615463, rho = -5.707249
# nSV = 362, nBSV = 42
# [LibSVM]..........*...........*.*
# optimization finished, #iter = 22417
# obj = -1456.995155, rho = -6.827802
# nSV = 331, nBSV = 36
# [LibSVM].............*..........*.*
# optimization finished, #iter = 24079
# obj = -2089.583243, rho = -6.058054
# nSV = 373, nBSV = 33
# [LibSVM].*
# optimization finished, #iter = 1889
# obj = -859.798306, rho = -6.154442
# nSV = 449, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1944
# obj = -1073.202213, rho = -6.183725
# nSV = 485, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2225
# obj = -623.550639, rho = -5.677468
# nSV = 431, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2573
# obj = -889.547644, rho = -6.529449
# nSV = 430, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2182
# obj = -1050.203374, rho = -6.047888
# nSV = 452, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1300
# obj = -1894.307939, rho = -6.264945
# nSV = 551, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1086
# obj = -2234.212272, rho = -5.951189
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1387
# obj = -1257.591535, rho = -5.177622
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1334
# obj = -2345.888334, rho = -5.902824
# nSV = 553, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1390
# obj = -2317.776513, rho = -5.721115
# nSV = 550, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 926
# obj = -2520.961324, rho = -6.205440
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 925
# obj = -2660.371129, rho = -5.958832
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1201
# obj = -1795.314738, rho = -4.991581
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1035
# obj = -3176.101298, rho = -5.684756
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1220
# obj = -3040.340792, rho = -5.466987
# nSV = 551, nBSV = 0
# [LibSVM]............................................................................................*..................................................................................*......................................................*
# optimization finished, #iter = 228571
# obj = -76213.512156, rho = -3.355302
# nSV = 362, nBSV = 186
# [LibSVM]................................................................................................................*............................................................................................................................................*............................*
# optimization finished, #iter = 280092
# obj = -90736.362451, rho = -3.392853
# nSV = 430, nBSV = 217
# [LibSVM]......................................................................................*.................................................................................*....*
# optimization finished, #iter = 170797
# obj = -59114.331647, rho = -0.686702
# nSV = 355, nBSV = 193
# [LibSVM]......................................................................*...................................................................................*
# optimization finished, #iter = 153262
# obj = -52168.270492, rho = -5.297637
# nSV = 325, nBSV = 177
# [LibSVM]..............................................................................................*............................................................................................*.........................................*
# optimization finished, #iter = 226298
# obj = -69488.541863, rho = -3.302048
# nSV = 378, nBSV = 181
# [LibSVM]...........................................*..................................*....*
# optimization finished, #iter = 81220
# obj = -6389.353892, rho = -5.747412
# nSV = 399, nBSV = 4
# [LibSVM]....................................*.........................................*.........................*
# optimization finished, #iter = 101653
# obj = -6955.516893, rho = -6.205581
# nSV = 437, nBSV = 5
# [LibSVM].....................................................*..........................................*..............*
# optimization finished, #iter = 109706
# obj = -5589.759680, rho = -5.594952
# nSV = 397, nBSV = 10
# [LibSVM].....................................................*...............................................*................*
# optimization finished, #iter = 115981
# obj = -3857.452636, rho = -6.788080
# nSV = 365, nBSV = 10
# [LibSVM].......................................*........................................*....................*
# optimization finished, #iter = 99502
# obj = -4804.532266, rho = -6.029149
# nSV = 386, nBSV = 9
# [LibSVM].*
# optimization finished, #iter = 1889
# obj = -859.798306, rho = -6.154442
# nSV = 449, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1944
# obj = -1073.202213, rho = -6.183725
# nSV = 485, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2225
# obj = -623.550639, rho = -5.677468
# nSV = 431, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2573
# obj = -889.547644, rho = -6.529449
# nSV = 430, nBSV = 0
# [LibSVM].*.*
# optimization finished, #iter = 2182
# obj = -1050.203374, rho = -6.047888
# nSV = 452, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1300
# obj = -1894.307939, rho = -6.264945
# nSV = 551, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1086
# obj = -2234.212272, rho = -5.951189
# nSV = 552, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1387
# obj = -1257.591535, rho = -5.177622
# nSV = 550, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1334
# obj = -2345.888334, rho = -5.902824
# nSV = 553, nBSV = 0
# [LibSVM].*
# optimization finished, #iter = 1390
# obj = -2317.776513, rho = -5.721115
# nSV = 550, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 926
# obj = -2520.961324, rho = -6.205440
# nSV = 554, nBSV = 0
# [LibSVM]*
# optimization finished, #iter = 925
# obj = -2660.371129, rho = -5.958832
# nSV = 553, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1201
# obj = -1795.314738, rho = -4.991581
# nSV = 558, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1035
# obj = -3176.101298, rho = -5.684756
# nSV = 560, nBSV = 0
# [LibSVM]*.*
# optimization finished, #iter = 1220
# obj = -3040.340792, rho = -5.466987
# nSV = 551, nBSV = 0
# [LibSVM].
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 3755
# obj = -1790.515906, rho = -5.374419
# nSV = 474, nBSV = 404
# GridSearchCV(estimator=SVR(gamma=0.1, verbose=True),
#              param_grid={'C': [1.0, 10.0, 100.0, 1000.0],
#                          'gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
svr_predict = svr.predict(x_test)

# %%
#  画出预测的图像，第二幅图为预测的图像，把缺失的数据补上
fig,ax = plt.subplots(figsize=(10, 5),layout='constrained')
ax.set_title("washingtong_winter_20120101-20120107")
ax.plot(y_test,label='true')
ax.plot(svr_predict,label='predict')
ax.grid()
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def cal_mse(y_hat, y):
    mse = (np.square(y_hat - y)).mean()
    return mse

# %%
mse = cal_mse(svr_predict, y_test)
mse
# Out:
# 0.5389367127212245

# %%
df = pd.DataFrame(data={
                'true_value': y_test,
                'predict': svr_predict
            })
df.to_csv("result/California_spring_20120401-20120407.csv", index=False)
